# %% [markdown]
# # Bone Segmentation for CT Scan #

# %%
import os
import requests
import io
import random
import glob
import zipfile
import shutil 
import csv
import pydicom

import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
tf.keras.backend.set_session(tf.Session(config=config))
import numpy as np

import matplotlib.pyplot as plt

import cv2

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model

from tensorflow.keras.layers import Input,Activation
from tensorflow.keras.layers import Conv2D,  MaxPooling2D, BatchNormalization, Conv2DTranspose, concatenate

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger

import tensorflow.keras.backend as K

from tensorflow.keras.optimizers import Adam

# %%
# Dataset 

def process_ircad_database(database_url, inputs_folder, bone_masks_folder, overwrite=False):
    
    # Database name will be assumed as the name on the last "/" before the ".zip"
    database_name = database_url.split('/')[-1].split(".zip")[0]
    
    print(50*'-')
    print("Processing: {0}".format(database_name))
    print(50*'-')
    
  
    database_folder = os.path.join(dataset_folder,database_name)
    
    if not os.path.exists(database_folder):
        os.makedirs(database_folder)
    
    # Request files
    r = requests.get(database_url)
    
    print("Request status code: {0}".format(r.status_code))
    
    z = zipfile.ZipFile(io.BytesIO(r.content))
    
    r.close()

    print("Database downloaded")
    print(50*'-')
    
    # Extract data to folder
    z.extractall(dataset_folder)
    z.close()
    
    print("Files extracted")
    print(50*'-')
    
    # Unzip Laled dicom
    label_dicom_zip_file = os.path.join(database_folder,'PATIENT_DICOM.zip')
    label_dicom_zip = zipfile.ZipFile(label_dicom_zip_file)
    label_dicom_zip.extractall(database_folder)
    label_dicom_zip.close()
    
    # Unzip masks dicom
    mask_dicom_zip_file = os.path.join(database_folder,'MASKS_DICOM.zip')
    mask_dicom_zip = zipfile.ZipFile(mask_dicom_zip_file)
    mask_dicom_zip.extractall(database_folder)
    mask_dicom_zip.close()
    
    print("Label and Masks extracted")
    print(50*'-')
    
    # Folders form input and bone masks dicom
    label_dicom_folder = os.path.join(database_folder,'PATIENT_DICOM') 
    bone_mask_dicom_folder = os.path.join(database_folder,'MASKS_DICOM','bone') 
    
    # Select all input and mask dicom files
    label_dicom_paths = glob.glob(os.path.join(label_dicom_folder,'*')) 
    bone_mask_dicom_paths = glob.glob(os.path.join(bone_mask_dicom_folder,'*')) 
    
    n_label = len(label_dicom_paths)
    n_bone_masks = len(bone_mask_dicom_paths) 
    print("Label files: {0}".format(n_label))
    print("Bone mask files: {0}".format(n_bone_masks))
    print(50*'-')
    # Check if we have files and both input and mask folder have the same number of files
    assert(len(label_dicom_paths) == len(bone_mask_dicom_paths) and len(label_dicom_paths) > 0 and len(bone_mask_dicom_paths) > 0)

    # Move files to appropriate folder

    current_index = 1
    
    # Update the current_index with the last file index on the folder
    if(overwrite == False):
        
        input_dicom_paths = glob.glob(os.path.join(inputs_folder,'*.dcm'))
        
        if(len(input_dicom_paths) == 0):
            current_index = 1
        else:
            # Grab the file names and extract just the number so input00012.dicom -> 12
            indices = [int(x.split("\\")[-1][5:10])  for x in input_dicom_paths]
            indices.sort()
            last_index = indices[-1]
            
            current_index = last_index + 1
    
    print("Moving files starting with index: {0}".format(current_index))
    print(50*'-')     
    
    for label_dicom_path, bone_mask_dicom_path in zip(label_dicom_paths, bone_mask_dicom_paths):
    
        assert(label_dicom_path.split("\\")[-1] == bone_mask_dicom_path.split("\\")[-1])
        
        new_input_dicom_path = os.path.join(inputs_folder,'input' + str(current_index).zfill(5) + ".dcm")
        new_bone_mask_dicom_path = os.path.join(bone_masks_folder,'mask' + str(current_index).zfill(5) + ".dcm")
        
        shutil.copy(label_dicom_path, new_input_dicom_path)
        shutil.copy(bone_mask_dicom_path, new_bone_mask_dicom_path)
        
        current_index +=1
    
    print("Moving process complete")
    print(50*'-')    
    
    # Delete temporaty database folder after we exctracted files we wantes
    shutil.rmtree(database_folder)
    
    print("Database folder excluded")
    print(50*'-')  
            
dataset_folder = 'dataset'

inputs_folder = os.path.join(dataset_folder,'inputs')
bone_masks_folder = os.path.join(dataset_folder,'bone_masks')

database_urls = [
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.1.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.2.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.3.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.4.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.5.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.6.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.7.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.8.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.9.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.10.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.11.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.12.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.13.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.14.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.15.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.16.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.17.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.18.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.19.zip',
                 'https://www.ircad.fr/softwares/3Dircadb/3Dircadb1/3Dircadb1.20.zip',
                 ]

# %%
dataset_folder = 'dataset'
inputs_folder = os.path.join(dataset_folder,'inputs')
bone_masks_folder = os.path.join(dataset_folder,'bone_masks')

# Create Dataset folder 
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)
    
# Create Input DICOM folder 
if not os.path.exists(inputs_folder):
    os.makedirs(inputs_folder)
    
# Create Bone Masks folder
if not os.path.exists(bone_masks_folder):
    os.makedirs(bone_masks_folder)

# %%
for database_url in database_urls:
    process_ircad_database(database_url,inputs_folder,bone_masks_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-202603b1f2de> in <module>
#       2 # The request library hangs sometimes after processing the last request. If that happens you have to start the process
#       3 # again from the dataset that you have stoped
# ----> 4 for database_url in database_urls:
#       5     process_ircad_database(database_url,inputs_folder,bone_masks_folder)
#
# NameError: name 'database_urls' is not defined

# %%
# Load data
# Load a DICOM file and convert it to [0-255] gray scale    
# For IRC  Dataset minimum value = -2048 and maximum value = 3247
def load_dicom(dicom_path):
    
    # Load dicom file
    dicom = pydicom.read_file(dicom_path)
    
    # Select only pixel image data
    pixel_data = dicom.pixel_array 

    # Normalize data using slope and interceptallow to transform the pixel values to Hounsfield Units    
    intercept = dicom.RescaleIntercept
    slope = dicom.RescaleSlope
    
    pixel_data = pixel_data * slope +intercept 

    image = np.zeros(pixel_data.shape)
    
    # Normalize image from 16 bits int to 8 bits unsigned int (JPG)
    image = (pixel_data + 65535)
    image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
    image[image > 255] = 255
    image[image < 1] = 0
          
    return image.astype('uint8')

# DICOM image files
input_files = glob.glob(os.path.join(inputs_folder,'*.dcm'))  
bone_mask_files = glob.glob(os.path.join(bone_masks_folder,'*.dcm'))   

# Sort names to avoid connecting wrong numbered files
input_files.sort()
bone_mask_files.sort()

assert(len(input_files) == len(bone_mask_files))

# (input image file, ground truth image file)
data = []
for input_image, bone_mask_image in zip(input_files, bone_mask_files):
    
    data.append((input_image,bone_mask_image))

# Plot some samples from dataset
n_samples = 5

for i in range(n_samples):
    
    # define the size of images
    f, (ax1, ax2) = plt.subplots(1, 2)
    f.set_figwidth(10)
    
    # randomly select a sample
    idx = np.random.randint(0, len(data))
    input_image_path, bone_mask_image_path = data[idx]
    
    input_image = load_dicom(input_image_path)
    bone_mask_image = load_dicom(bone_mask_image_path) 
    
    ax1.imshow(input_image, cmap = 'gray')
    ax1.set_title('Input Image # {0}'.format(idx))
    
    ax2.imshow(bone_mask_image, cmap = 'gray')
    ax2.set_title('Bone Mask Image # {0}'.format(idx))

# %%
# Data Augmentation
    
# Resize Image

class Resize(object):
    
    def __init__(self, input_size, output_size):
        
        assert isinstance(input_size,(int, tuple))
        assert isinstance(output_size,(int, tuple))
        
        self.input_size = input_size
        self.output_size = output_size    
        
    def __call__(self, input_image, mask_image):     
           
        h_in, w_in = input_image.shape[:2]
        h_out, w_out = mask_image.shape[:2]
        
        if isinstance(self.input_size, int):
            if h_in > w_in:
                new_h_in, new_w_in = self.input_size * h_in / w_in, self.input_size
            else:
                new_h_in, new_w_in = self.input_size, self.input_size * w_in / h_in
        else:
            new_h_in, new_w_in = self.input_size
        
        if isinstance(self.output_size, int):
            if h_out > w_out:
                new_h_out, new_w_out = self.output_size * h_out / w_out, self.output_size
            else:
                new_h_out, new_w_out = self.output_size, self.output_size * w_out / h_out
        else:
            new_h_out, new_w_out = self.output_size

        new_h_in, new_w_in = int(new_h_in), int(new_w_in)
        new_h_out, new_w_out = int(new_h_out), int(new_w_out)

        input_image = cv2.resize(input_image, (new_w_in, new_h_in))
        mask_image = cv2.resize(mask_image, (new_w_out, new_h_out)) 
        
        return input_image,  mask_image


# Translate Image
   
class RandomTranslation(object):

    def __init__(self, ratio = 0.4, background_color = (0) , prob=0.5):
        
        self.background_color  = background_color
        self.ratio = ratio
        self.prob  = prob
        
    def __call__(self, input_image, mask_image):
                
        if random.uniform(0, 1) <= self.prob:
            
            img_h, img_w = input_image.shape
            
            x = int(np.random.uniform(-self.ratio,self.ratio) * img_w)
            y = int(np.random.uniform(-self.ratio,self.ratio) * img_h)

            M = np.float32([[1, 0, x],
                            [0, 1, y]])
                
            input_image_translated = cv2.warpAffine(input_image,M,(img_w,img_h), borderValue=self.background_color)
            imask_image_translated = cv2.warpAffine(mask_image,M,(img_w,img_h), borderValue=self.background_color)
            
            return input_image_translated , imask_image_translated
           
        return input_image, mask_image


# Scale Image

class RandomScale(object):

    def __init__(self, lower = 0.4, upper = 1.4, background_color = (0) , prob=0.5):
        
        self.background_color = background_color
        self.lower = lower
        self.upper = upper
        self.prob  = prob  
        
    def __call__(self, input_image, mask_image):
                
        if random.uniform(0, 1) <= self.prob:
            
            input_img_h, input_img_w = input_image.shape
            mask_img_h, mask_img_w = mask_image.shape
            
            # Create canvas with random ration between lower and upper
            ratio = random.uniform(self.lower,self.upper)
            
            scale_x = ratio
            scale_y = ratio
            
            # Scale the image
            scaled_input_image = cv2.resize(input_image.astype('float32'),(0,0),fx=scale_x,fy=scale_y)
            scaled_mask_image = cv2.resize(mask_image.astype('float32'),(0,0),fx=scale_x,fy=scale_y)
            
            top = 0
            left = 0
            
            if ratio < 1:
                    
                # Input image
                background = np.zeros((input_img_h, input_img_w), dtype = np.uint8)
                
                background[:,:] = self.background_color 
            
                y_lim = int(min(scale_x,1)*input_img_h)
                x_lim = int(min(scale_y,1)*input_img_w)
                
                top  = (input_img_h - y_lim) // 2
                left = (input_img_w - x_lim) // 2

                background[top:y_lim+top,left:x_lim+left] = scaled_input_image[:y_lim,:x_lim]
                
                scaled_input_image = background
                
                # Mask image                
                background = np.zeros((mask_img_h, mask_img_w), dtype = np.uint8)
                
                background[:,:] = self.background_color 
                
                y_lim = int(min(scale_x,1)*mask_img_h)
                x_lim = int(min(scale_y,1)*mask_img_w)
                
                top  = (mask_img_h - y_lim) // 2
                left = (mask_img_w - x_lim) // 2
                
                background[top:y_lim+top,left:x_lim+left] = scaled_mask_image[:y_lim,:x_lim]
                
                scaled_mask_image = background
                    
            else:
                
                top  = (scaled_input_image.shape[0] -  input_img_h) // 2
                left = (scaled_input_image.shape[1] -  input_img_w) // 2
                
                scaled_input_image = scaled_input_image[top:input_img_h+top,left:input_img_w+left]
                
                top  = (scaled_mask_image.shape[0] -  mask_img_h) // 2
                left = (scaled_mask_image.shape[1] -  mask_img_w) // 2
                
                scaled_mask_image = scaled_mask_image[top:mask_img_h+top,left:mask_img_w+left]
                         
            return scaled_input_image, scaled_mask_image

        return input_image, mask_image
    

# Flip image
   
class RandomFlip(object):
 
    def __init__(self, prob=0.5):

        self.prob = prob
        
    def __call__(self, input_image, mask_image):
        
        if random.uniform(0, 1) <= self.prob:
        
            # Get image shape
            h, w = input_image.shape[:2]
            
            # Flip image
            input_image = input_image[:, ::-1]
            
            # Get image shape
            h, w = mask_image.shape[:2]
            
            # Flip image
            mask_image = mask_image[:, ::-1]
            
            # Random flip horizontally
            if random.uniform(0, 1) <= 0.5 :
                
                input_image = np.flip(input_image)
                mask_image = np.flip(mask_image)
            
            return input_image, mask_image
        
        return input_image, mask_image


# Change image brightness

class RandomBrightness():
    
    def __init__(self, lower = -25, upper = 25, prob = 0.5):

        self.lower = lower
        self.upper = upper
        self.prob = prob
    
    def __call__(self, input_image,  mask_image):
        
        if random.uniform(0, 1) <= self.prob:
            
            amount = int(random.uniform(self.lower, self.upper))
            
            input_image = np.clip(input_image + amount, 0, 255).astype("uint8")
        
            return input_image, mask_image
        
        return input_image, mask_image


# Change image contrast

class RandomContrast():
    
    def __init__(self, lower = 0.5, upper = 1.5, prob = 0.5):

        self.lower = lower
        self.upper = upper
        self.prob = prob
    
    def __call__(self, input_image,  mask_image):
        
        if random.uniform(0, 1) <= self.prob:
            
            amount = random.uniform(self.lower, self.upper)
            
            input_image = np.clip(input_image * amount, 0, 255).astype("uint8")
        
            return input_image, mask_image
        
        return input_image, mask_image
    
    
# Gaussian Noise
   
class GaussianNoise(object):
    
    def __init__(self,mean=0.0, var=0.1, prob=0.5):

        self.mean = mean
        self.var = var
        self.prob = prob
    
    def __call__(self, input_image, mask_image):
        
        if random.uniform(0, 1) <= self.prob:
        
             # Get image shape
            h, w = input_image.shape[:2]
            
            sigma = self.var **0.5
            
            gauss = np.random.normal(self.mean,sigma,(w,h))
            gauss = gauss.reshape(w,h)
            
            noise_input_image = input_image + gauss
            
            return noise_input_image, mask_image
        
        return input_image, mask_image



# Normalize

class Normalize(object):
    
    """Normalize the color range to [0,1].""" 
       
    def __call__(self, input_image, mask_image):
                    
        return input_image / 255 , mask_image / 255 


# Test Data Augmentation 

def plot_transformation(transformation, n_samples = 3, normalize = False):

    for i in range(n_samples):
    
        # define the size of images
        f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
        f.set_figwidth(14)

        # randomly select a sample
        idx = np.random.randint(0, len(data))
        input_image_path, bone_mask_image_path = data[idx]
    
        input_image = load_dicom(input_image_path)
        bone_mask_image = load_dicom(bone_mask_image_path)
        
        if normalize:
            norm = Normalize()
            input_image, bone_mask_image = norm(input_image, bone_mask_image)

        new_input_image, new_bone_mask_image = transformation(input_image, bone_mask_image)
        
        ax1.imshow(input_image , cmap = 'gray')
        ax1.set_title('Original Input')
        
        ax2.imshow(new_input_image , cmap = 'gray')
        ax2.set_title(type(transformation).__name__)

        ax3.imshow(bone_mask_image , cmap = 'gray')
        ax3.set_title('Original Bone Mask')
        
        ax4.imshow(new_bone_mask_image , cmap = 'gray')
        ax4.set_title(type(transformation).__name__)

        plt.show()

# %%
# Resize Test

resize = Resize((512, 512),(512, 512))
plot_transformation(resize)

# %%
# Random Translation

translation = RandomTranslation(ratio = 0.2, prob=1.0)
plot_transformation(translation)

# %%
# Random Scale

scale = RandomScale(prob=1.0)
plot_transformation(scale)

# %%
# Random Brightness Test

bright = RandomBrightness(prob=1.0)
plot_transformation(bright)

# %%
# Random Contrast Test

contrast = RandomContrast(lower = 0.3, upper = 1.9,prob=0.5)
plot_transformation(contrast)

# %%
# Gaussian Noise Test

noise = GaussianNoise(mean=0.0, var=0.01, prob=1.0)
plot_transformation(noise, normalize = True)

# %%
# Normalize Test

normalize = Normalize()
plot_transformation(normalize)

# %%
# Create Dataset
 
# Create X, y tuple from image_path, key_pts tuple
def createXy(data, transformations = None):
    
    input_image_path, bone_mask_image_path = data
    
    input_image = load_dicom(input_image_path) 
    bone_mask_image = load_dicom(bone_mask_image_path) 
    
    # Apply transformations for the tuple (image, labels, boxes)
    if transformations:
        for t in transformations:
            input_image, bone_mask_image = t(input_image, bone_mask_image)
            
    input_image = np.expand_dims(input_image, axis = -1)     
    bone_mask_image = np.expand_dims(bone_mask_image, axis = -1)            
            
    return input_image, bone_mask_image

# Generator for using with model
def generator(data, transformations = None, batch_size = 4, shuffle_data= True):
    
    n_samples = len(data)
    
    # Loop forever for the generator
    while 1:
        
        if shuffle_data:
            data = shuffle(data)
        
        for offset in range(0, n_samples, batch_size): 
            
            batch_samples = data[offset:offset + batch_size]
            
            X = []
            y = []
            
            for sample_data in batch_samples:
                
                image, target = createXy(sample_data, transformations)

                X.append(image)
                y.append(target)
                
            X = np.asarray(X).astype('float32')
            y = np.asarray(y).astype('float32')
            
            yield (shuffle(X, y))

# %%
# UNet Model
def unet_encoder(inputs,filters, block_id):
    
    x = Conv2D(filters, kernel_size=(3,3), padding='same' , kernel_initializer='he_normal', name='block_' + str(block_id) + '_unet_encoder_conv2d_1')(inputs)
    x = BatchNormalization(name='block_' + str(block_id) + '_unet_encoder_conv_batch_1')(x)
    x = Activation('relu', name='block_' + str(block_id) + '_unet_encoder_relu_1')(x)
    
    x = Conv2D(filters, kernel_size=(3,3), padding='same' , kernel_initializer='he_normal', name='block_' + str(block_id) + '_unet_encoder_conv2d_2')(x)
    x = BatchNormalization(name='block_' + str(block_id) + '_unet_encoder_conv_batch_2')(x)
    x = Activation('relu', name='block_' + str(block_id) + '_unet_encoder_relu_2')(x)
    
    return x
                
def unet_encoder_pool(inputs,filters, block_id):
    
    x = unet_encoder(inputs, filters, block_id)
    x = MaxPooling2D(pool_size=(2,2), name='block_' + str(block_id) + '_unet_pooling')(x)
    
    return x

def unet_decoder(inputs_a, inputs_b, filters, block_id):
    
    x = Conv2DTranspose(filters, kernel_size=(2,2), strides=(2,2), padding='same')(inputs_a)
    
    x = concatenate([x, inputs_b],axis=3)
    
    x = Conv2D(filters, kernel_size=(3,3), padding='same' , kernel_initializer='he_normal', name='block_' + str(block_id) + '_unet_decoder_conv2d_1')(x)
    x = BatchNormalization(name='block_' + str(block_id) + '_unet_decoder_conv_batch_1')(x)
    x = Activation('relu', name='block_' + str(block_id) + '_unet_decoder_relu_1')(x)
    
    x = Conv2D(filters, kernel_size=(3,3), padding='same' , kernel_initializer='he_normal', name='block_' + str(block_id) + '_unet_decoder_conv2d_2')(x)
    x = BatchNormalization(name='block_' + str(block_id) + '_unet_decoder_conv_batch_2')(x)
    x = Activation('relu', name='block_' + str(block_id) + '_unet_decoder_relu_2')(x)
    
    return x
              
def UNet(input_shape=(512,512,1)):
    
    Image = Input(shape=input_shape)
    
    encoder = unet_encoder_pool(Image,   filters=32,  block_id=0)
    encoder = unet_encoder_pool(encoder, filters=64,  block_id=1)
    encoder = unet_encoder_pool(encoder, filters=128, block_id=2)
    encoder = unet_encoder_pool(encoder, filters=256, block_id=3)
    encoder = unet_encoder(encoder, filters=512, block_id=4)
    
    encoder_model = Model(inputs=Image,outputs=encoder)

    tensor1 = encoder_model.get_layer('block_3_unet_encoder_relu_2').output
    tensor2 = encoder_model.get_layer('block_2_unet_encoder_relu_2').output
    tensor3 = encoder_model.get_layer('block_1_unet_encoder_relu_2').output
    tensor4 = encoder_model.get_layer('block_0_unet_encoder_relu_2').output
    
    decoder = unet_decoder(encoder, tensor1, filters=256, block_id = 4)
    decoder = unet_decoder(decoder, tensor2, filters=128, block_id = 5)
    decoder = unet_decoder(decoder, tensor3, filters=64, block_id = 6)
    decoder = unet_decoder(decoder, tensor4, filters=32, block_id = 7)
    
    decoder = Conv2D(1,kernel_size=(1,1),strides=(1,1), activation='sigmoid')(decoder)
    
    model = Model(inputs=Image, outputs=decoder)
    
    return model

# UNet Loss
class UNetLoss():
    
    def __init__(self, smooth = 1):
        
        self.smooth = smooth
    
    def calculate_loss(self, y_true, y_pred):
        
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        
        intersection = K.sum(y_true_f * y_pred_f)
        coefficient = (2. * intersection + self.smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + self.smooth)
        loss = 1 - coefficient
        return loss

# %%
# Training pipeline

# Data augmentation 
train_transformations = [ 
        RandomBrightness(prob=0.5),
        RandomContrast(prob=0.5),
        RandomTranslation(ratio=0.2, prob=0.5),
        RandomScale(lower=0.8,upper=1.2, prob=0.5),
        RandomFlip(prob=0.5),
        Resize((512,512),(512,512)),
        GaussianNoise(mean=0.0, var=0.01, prob=1.0),
        Normalize()
        ]

test_transformations = [
        RandomBrightness(prob=0.5),
        RandomContrast(prob=0.5),
        RandomTranslation(ratio=0.2, prob=0.5),
        RandomScale(lower=0.8,upper=1.2, prob=0.5),
        RandomFlip(prob=0.5),
        Resize((512,512),(512,512)),
        GaussianNoise(mean=0.0, var=0.01, prob=1.0),
        Normalize()
        ]

valid_transformations = [
        RandomBrightness(prob=0.5),
        RandomContrast(prob=0.5),
        RandomTranslation(ratio=0.2, prob=0.5),
        RandomScale(lower=0.8,upper=1.2, prob=0.5),
        RandomFlip(prob=0.5),
        Resize((512,512),(512,512)),
        GaussianNoise(mean=0.0, var=0.01, prob=1.0),
        Normalize()
        ]

# Hyperparameters
epochs = 150
batch_size = 4 
learning_rate = 0.001
weight_decay = 5e-4
momentum = .9

train_data, test_valid_data = train_test_split(data, test_size=0.20, random_state=42)
test_data, valid_data = train_test_split(test_valid_data, test_size=0.50, random_state=42)

print('Size of train data: {0}'.format(len(train_data)))
print('Size of test data: {0}'.format(len(test_data)))
print('Size of valid data: {0}'.format(len(valid_data)))

train_generator = generator(train_data, train_transformations, batch_size)
test_generator = generator(test_data, test_transformations, batch_size)

# callbacks
model_path = 'saved_models'

model = UNet()


# Create loss function
loss = UNetLoss()

# Create Optimizer
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

# Compile model for training
model.compile(optimizer, loss = loss.calculate_loss, metrics=['accuracy'])

# File were the best model will be saved during checkpoint     
model_file = os.path.join(model_path,'bone_segmentation-{val_loss:.4f}.h5')

# Check point for saving the best model
check_pointer = ModelCheckpoint(model_file, monitor='val_loss', mode='min',verbose=1, save_best_only=True)

# Logger to store loss on a csv file
csv_logger = CSVLogger(filename='bone_segmentation.csv',separator=',', append=True)
# Out:
# Size of train data: 4516
# Size of test data: 565
# Size of valid data: 565
# WARNING:tensorflow:From C:\Users\1\anaconda3\envs\tensorflowGPU\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.fit_generator(train_generator,steps_per_epoch=int(len(train_data) / batch_size), epochs=epochs)

# %%
# Predict

n_samples = 5

for i in range(n_samples):
    
    f, (ax1, ax2, ax3) = plt.subplots(1, 3)
    f.set_figwidth(14)
    
    # randomly select a sample
    idx = np.random.randint(0, len(valid_data))
    sample = valid_data[idx]
    
    # Read input file
    input_image_path, bone_mask_image_path = sample
    
    input_image = load_dicom(input_image_path) 
    bone_mask_image = load_dicom(bone_mask_image_path) 
    
    input_image_copy = np.copy(input_image)
    bone_mask_image_copy = np.copy(bone_mask_image)

    # Apply transformations to input and background image
    for t in valid_transformations:
        input_image_copy,bone_mask_image_copy = t(input_image_copy, bone_mask_image_copy)
            
    input_image_copy = np.expand_dims(input_image_copy, axis = -1)     
    bone_mask_image_copy = np.expand_dims(bone_mask_image_copy, axis = -1)  
    
    # Predict 
    bone_mask_pred = model.predict(input_image_copy[np.newaxis,...]) 
    
     # Squeeze
    input_image_copy = np.squeeze(input_image_copy)
    bone_mask_image_copy = np.squeeze(bone_mask_image_copy)
    bone_mask_pred = np.squeeze(bone_mask_pred)

    bone_mask_pred[bone_mask_pred > 0.5] = 1
    bone_mask_pred[bone_mask_pred <= 0.5] = 0

    # Plot 
    ax1.set_title('Input Image # {0}'.format(idx))
    ax1.imshow(input_image_copy , cmap='gray')
    
    ax2.set_title('True Bone Mask # {0}'.format(idx))
    ax2.imshow(bone_mask_image_copy, cmap='gray')
    
    ax3.set_title('Predicted Bone Mask # {0}'.format(idx))
    ax3.imshow(bone_mask_pred, cmap='gray')

# %%
model.save(f'UNET-BoneSegmentation_{512}_{512}.h5')

# %%
# Test again

n_samples = 5

for i in range(n_samples):
    
    f, (ax1, ax2, ax3) = plt.subplots(1, 3)
    f.set_figwidth(14)
    
    # randomly select a sample
    idx = np.random.randint(0, len(valid_data))
    sample = valid_data[idx]
    
    # Read input file
    input_image_path, bone_mask_image_path = sample
    
    input_image = load_dicom(input_image_path) 
    bone_mask_image = load_dicom(bone_mask_image_path) 
    
    input_image_copy = np.copy(input_image)
    bone_mask_image_copy = np.copy(bone_mask_image)

    # Apply transformations to input and background image
    for t in valid_transformations:
        input_image_copy,bone_mask_image_copy = t(input_image_copy, bone_mask_image_copy)
            
    input_image_copy = np.expand_dims(input_image_copy, axis = -1)     
    bone_mask_image_copy = np.expand_dims(bone_mask_image_copy, axis = -1)  
    
    # Predict 
    bone_mask_pred = model.predict(input_image_copy[np.newaxis,...]) 
    
     # Squeeze
    input_image_copy = np.squeeze(input_image_copy)
    bone_mask_image_copy = np.squeeze(bone_mask_image_copy)
    bone_mask_pred = np.squeeze(bone_mask_pred)

    bone_mask_pred[bone_mask_pred > 0.5] = 1
    bone_mask_pred[bone_mask_pred <= 0.5] = 0

    # Plot 
    ax1.set_title('Input Image # {0}'.format(idx))
    ax1.imshow(input_image_copy , cmap='gray')
    
    ax2.set_title('True Bone Mask # {0}'.format(idx))
    ax2.imshow(bone_mask_image_copy, cmap='gray')
    
    ax3.set_title('Predicted Bone Mask # {0}'.format(idx))
    ax3.imshow(bone_mask_pred, cmap='gray')

# %%
# Evaluate the model

model.load_weights(os.path.join(Bone Segmentation,'<path to model.h5>'), by_name=False)

measures = np.zeros((len(data),11))
statistics = []
    
for i, sample in enumerate(data):
    
    # Retrieve tuple
    input_image_path, bone_mask_image_path= sample
    
    print("input: {0} , gt: {1}".format(input_image_path.split("\\")[-1], bone_mask_image_path.split("\\")[-1]))
    
    # Read input file
    input_image = load_dicom(input_image_path) 
    bone_mask_image = load_dicom(bone_mask_image_path) 
    
    # Make a copy for safety
    input_image_copy = np.copy(input_image)
    bone_mask_image_copy = np.copy(bone_mask_image)
    

    for t in valid_transformations:
        input_image_copy,bone_mask_image_copy = t(input_image_copy, bone_mask_image_copy)

    # Correct single dimensions
    input_image_copy = np.expand_dims(input_image_copy, axis = -1)     
    bone_mask_image_copy = np.expand_dims(bone_mask_image_copy, axis = -1)  
    
    # Predict 
    bone_mask_pred = model.predict(input_image_copy[np.newaxis,...]) 
    
     # Squeeze
    input_image_copy = np.squeeze(input_image_copy)
    y_true = np.squeeze(bone_mask_image_copy)
    y_pred = np.squeeze(bone_mask_pred)
    
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <= 0.5] = 0
    
    plt.imsave('dataset\\inputs\\' + input_image_path.split("\\")[-1].split('.')[0] + ".jpg" , input_image_copy, cmap='gray')
    plt.imsave('dataset\\bone_masks\\' + bone_mask_image_path.split("\\")[-1].split('.')[0] + ".jpg" , y_true, cmap='gray')

        
    # Calculate True Positive, True Negative, False Positive, False Negative
    TP = np.sum(np.logical_and(y_pred == 1, y_true == 1))
    TN = np.sum(np.logical_and(y_pred == 0, y_true == 0))
    FP = np.sum(np.logical_and(y_pred == 1, y_true == 0))
    FN = np.sum(np.logical_and(y_pred == 0, y_true == 1))

    # Calculate Recall
    recall = TP / (TP + FN)
    
    # Calculate Precision
    precision =  TP / (TP + FP)
    
    # Calculate Recall
    Dice = 2 * TP / (2 * TP + FP + FN)
    
    # Calculate Specificity
    Jaccard = Dice / (2 - Dice)

    # Calculate False Positive Rate
    FPR =  FP / (FP + TN)
    
    # Calculate False Negative Rate
    FNR = FN / (TP + FN)
    
    # Calculate Percentage of Wrong Classifications
    PWC =  100 * (FN + FP) / (TP + FN + FP + TN)

    stats = { 'input_image': input_image_path,
              'bone_mask_image' : bone_mask_image_path,
              'TP' : TP,
              'TN' : TN,
              'FP' : FP,
              'FN' : FN,
              'recall' : recall,
              'precision' : precision,
              'FPR' : FPR,
              'FNR' : FNR,
              'PWC' : PWC,
              'Jaccard' : Jaccard,
              'Dice' : Dice
            }
    
    statistics.append(stats)
    
    measures[i][0] = TP
    measures[i][1] = TN
    measures[i][2] = FP
    measures[i][3] = FN
    measures[i][4] = recall
    measures[i][5] = precision
    measures[i][6] = FPR
    measures[i][7] = FNR
    measures[i][8] = PWC
    measures[i][9] = Jaccard
    measures[i][10] = Dice

# Replace NaN by zeros
measures[np.isnan(measures)] = 0

# Calculate Mean Average for all our statistics
mean_score = measures.mean(axis=0)
max_score = measures.max(axis=0)
min_score = measures.min(axis=0)

# Print Average Statistics
print(50*'-')
print('Recall: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[4],max_score[4],min_score[4]))
print(50*'-')
print('Precision: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[5],max_score[5],min_score[5]))
print(50*'-')
print('False Positive Rate: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[6],max_score[6],min_score[6]))
print(50*'-')
print('Calculate False Negative Rate: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[7],max_score[7],min_score[7]))
print(50*'-')
print('Percentage of Wrong Classifications: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[8],max_score[8],min_score[8]))
print(50*'-')
print('Jaccard: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[9],max_score[9],min_score[9]))
print(50*'-')
print('Dice: Avg:{0:.2f} , Max: {1:.2f} , Min: {2:.2f}'.format(mean_score[10],max_score[10],min_score[10]))
print(50*'-')

# Create Confusion Matrix
cm = np.zeros((2,2))
cm[0][0] = mean_score[0]
cm[0][1] = mean_score[2]
cm[1][0] = mean_score[3]
cm[1][1] = mean_score[1]

print(50*'-')
print('Confusion Matrix')
plt.matshow(cm)
plt.colorbar()
print(50*'-')

# Save results on a file
results_folder = 'results'

# Create Dataset folder 
if not os.path.exists(results_folder):
    os.makedirs(results_folder)
    
csv_columns = ['input_image','bone_mask_image','TP','TN','FP','FN','recall','precision','FPR','FNR','PWC','Jaccard','Dice']

csv_file = os.path.join(results_folder, 'bone_segmentation_stats.csv')

try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns, lineterminator = '\n')
        writer.writeheader()
        for data in statistics:
            writer.writerow(data)
except IOError:
    print("I/O error")
# Out:
# input: input00001.dcm , gt: mask00001.dcm
# input: input00002.dcm , gt: mask00002.dcm
# input: input00003.dcm , gt: mask00003.dcm
# input: input00004.dcm , gt: mask00004.dcm
# input: input00005.dcm , gt: mask00005.dcm
# input: input00006.dcm , gt: mask00006.dcm
# input: input00007.dcm , gt: mask00007.dcm
# input: input00008.dcm , gt: mask00008.dcm
# input: input00009.dcm , gt: mask00009.dcm
# input: input00010.dcm , gt: mask00010.dcm
# input: input00011.dcm , gt: mask00011.dcm
# input: input00012.dcm , gt: mask00012.dcm
# input: input00013.dcm , gt: mask00013.dcm
# input: input00014.dcm , gt: mask00014.dcm
# input: input00015.dcm , gt: mask00015.dcm
# input: input00016.dcm , gt: mask00016.dcm
# input: input00017.dcm , gt: mask00017.dcm
# input: input00018.dcm , gt: mask00018.dcm
# input: input00019.dcm , gt: mask00019.dcm
# input: input00020.dcm , gt: mask00020.dcm
# input: input00021.dcm , gt: mask00021.dcm
# input: input00022.dcm , gt: mask00022.dcm
# input: input00023.dcm , gt: mask00023.dcm
# input: input00024.dcm , gt: mask00024.dcm
# input: input00025.dcm , gt: mask00025.dcm
# input: input00026.dcm , gt: mask00026.dcm
# input: input00027.dcm , gt: mask00027.dcm
# input: input00028.dcm , gt: mask00028.dcm
# input: input00029.dcm , gt: mask00029.dcm
# input: input00030.dcm , gt: mask00030.dcm
# input: input00031.dcm , gt: mask00031.dcm
# input: input00032.dcm , gt: mask00032.dcm
# input: input00033.dcm , gt: mask00033.dcm
# input: input00034.dcm , gt: mask00034.dcm
# input: input00035.dcm , gt: mask00035.dcm
# input: input00036.dcm , gt: mask00036.dcm
# input: input00037.dcm , gt: mask00037.dcm
# input: input00038.dcm , gt: mask00038.dcm
# input: input00039.dcm , gt: mask00039.dcm
# input: input00040.dcm , gt: mask00040.dcm
# input: input00041.dcm , gt: mask00041.dcm
# input: input00042.dcm , gt: mask00042.dcm
# input: input00043.dcm , gt: mask00043.dcm
# input: input00044.dcm , gt: mask00044.dcm
# input: input00045.dcm , gt: mask00045.dcm
# input: input00046.dcm , gt: mask00046.dcm
# input: input00047.dcm , gt: mask00047.dcm
# input: input00048.dcm , gt: mask00048.dcm
# input: input00049.dcm , gt: mask00049.dcm
# input: input00050.dcm , gt: mask00050.dcm
# input: input00051.dcm , gt: mask00051.dcm
# input: input00052.dcm , gt: mask00052.dcm
# input: input00053.dcm , gt: mask00053.dcm
# input: input00054.dcm , gt: mask00054.dcm
# input: input00055.dcm , gt: mask00055.dcm
# input: input00056.dcm , gt: mask00056.dcm
# input: input00057.dcm , gt: mask00057.dcm
# input: input00058.dcm , gt: mask00058.dcm
# input: input00059.dcm , gt: mask00059.dcm
# input: input00060.dcm , gt: mask00060.dcm
# input: input00061.dcm , gt: mask00061.dcm
# input: input00062.dcm , gt: mask00062.dcm
# input: input00063.dcm , gt: mask00063.dcm
# input: input00064.dcm , gt: mask00064.dcm
# input: input00065.dcm , gt: mask00065.dcm
# input: input00066.dcm , gt: mask00066.dcm
# input: input00067.dcm , gt: mask00067.dcm
# input: input00068.dcm , gt: mask00068.dcm
# input: input00069.dcm , gt: mask00069.dcm
# input: input00070.dcm , gt: mask00070.dcm
# input: input00071.dcm , gt: mask00071.dcm
# input: input00072.dcm , gt: mask00072.dcm
# input: input00073.dcm , gt: mask00073.dcm
# input: input00074.dcm , gt: mask00074.dcm
# input: input00075.dcm , gt: mask00075.dcm
# input: input00076.dcm , gt: mask00076.dcm
# input: input00077.dcm , gt: mask00077.dcm
# input: input00078.dcm , gt: mask00078.dcm
# input: input00079.dcm , gt: mask00079.dcm
# input: input00080.dcm , gt: mask00080.dcm
# input: input00081.dcm , gt: mask00081.dcm
# input: input00082.dcm , gt: mask00082.dcm
# input: input00083.dcm , gt: mask00083.dcm
# input: input00084.dcm , gt: mask00084.dcm
# input: input00085.dcm , gt: mask00085.dcm
# input: input00086.dcm , gt: mask00086.dcm
# input: input00087.dcm , gt: mask00087.dcm
# input: input00088.dcm , gt: mask00088.dcm
# input: input00089.dcm , gt: mask00089.dcm
# input: input00090.dcm , gt: mask00090.dcm
# input: input00091.dcm , gt: mask00091.dcm
# input: input00092.dcm , gt: mask00092.dcm
# input: input00093.dcm , gt: mask00093.dcm
# input: input00094.dcm , gt: mask00094.dcm
# input: input00095.dcm , gt: mask00095.dcm
# input: input00096.dcm , gt: mask00096.dcm
# input: input00097.dcm , gt: mask00097.dcm
# input: input00098.dcm , gt: mask00098.dcm
# input: input00099.dcm , gt: mask00099.dcm
# input: input00100.dcm , gt: mask00100.dcm
# input: input00101.dcm , gt: mask00101.dcm
# input: input00102.dcm , gt: mask00102.dcm
# input: input00103.dcm , gt: mask00103.dcm
# input: input00104.dcm , gt: mask00104.dcm
# input: input00105.dcm , gt: mask00105.dcm
# input: input00106.dcm , gt: mask00106.dcm
# input: input00107.dcm , gt: mask00107.dcm
# input: input00108.dcm , gt: mask00108.dcm
# input: input00109.dcm , gt: mask00109.dcm
# input: input00110.dcm , gt: mask00110.dcm
# input: input00111.dcm , gt: mask00111.dcm
# input: input00112.dcm , gt: mask00112.dcm
# input: input00113.dcm , gt: mask00113.dcm
# input: input00114.dcm , gt: mask00114.dcm
# input: input00115.dcm , gt: mask00115.dcm
# input: input00116.dcm , gt: mask00116.dcm
# input: input00117.dcm , gt: mask00117.dcm
# input: input00118.dcm , gt: mask00118.dcm
# input: input00119.dcm , gt: mask00119.dcm
# input: input00120.dcm , gt: mask00120.dcm
# input: input00121.dcm , gt: mask00121.dcm
# input: input00122.dcm , gt: mask00122.dcm
# input: input00123.dcm , gt: mask00123.dcm
# input: input00124.dcm , gt: mask00124.dcm
# input: input00125.dcm , gt: mask00125.dcm
# input: input00126.dcm , gt: mask00126.dcm
# input: input00127.dcm , gt: mask00127.dcm
# input: input00128.dcm , gt: mask00128.dcm
# input: input00129.dcm , gt: mask00129.dcm
# input: input00130.dcm , gt: mask00130.dcm
# input: input00131.dcm , gt: mask00131.dcm
# input: input00132.dcm , gt: mask00132.dcm
# input: input00133.dcm , gt: mask00133.dcm
# input: input00134.dcm , gt: mask00134.dcm
# input: input00135.dcm , gt: mask00135.dcm
# input: input00136.dcm , gt: mask00136.dcm
# input: input00137.dcm , gt: mask00137.dcm
# input: input00138.dcm , gt: mask00138.dcm
# input: input00139.dcm , gt: mask00139.dcm
# input: input00140.dcm , gt: mask00140.dcm
# input: input00141.dcm , gt: mask00141.dcm
# input: input00142.dcm , gt: mask00142.dcm
# input: input00143.dcm , gt: mask00143.dcm
# input: input00144.dcm , gt: mask00144.dcm
# input: input00145.dcm , gt: mask00145.dcm
# input: input00146.dcm , gt: mask00146.dcm
# input: input00147.dcm , gt: mask00147.dcm
# input: input00148.dcm , gt: mask00148.dcm
# input: input00149.dcm , gt: mask00149.dcm
# input: input00150.dcm , gt: mask00150.dcm
# input: input00151.dcm , gt: mask00151.dcm
# input: input00152.dcm , gt: mask00152.dcm
# input: input00153.dcm , gt: mask00153.dcm
# input: input00154.dcm , gt: mask00154.dcm
# input: input00155.dcm , gt: mask00155.dcm
# input: input00156.dcm , gt: mask00156.dcm
# input: input00157.dcm , gt: mask00157.dcm
# input: input00158.dcm , gt: mask00158.dcm
# input: input00159.dcm , gt: mask00159.dcm
# input: input00160.dcm , gt: mask00160.dcm
# input: input00161.dcm , gt: mask00161.dcm
# input: input00162.dcm , gt: mask00162.dcm
# input: input00163.dcm , gt: mask00163.dcm
# input: input00164.dcm , gt: mask00164.dcm
# input: input00165.dcm , gt: mask00165.dcm
# input: input00166.dcm , gt: mask00166.dcm
# input: input00167.dcm , gt: mask00167.dcm
# input: input00168.dcm , gt: mask00168.dcm
# input: input00169.dcm , gt: mask00169.dcm
# input: input00170.dcm , gt: mask00170.dcm
# input: input00171.dcm , gt: mask00171.dcm
# input: input00172.dcm , gt: mask00172.dcm
# input: input00173.dcm , gt: mask00173.dcm
# input: input00174.dcm , gt: mask00174.dcm
# input: input00175.dcm , gt: mask00175.dcm
# input: input00176.dcm , gt: mask00176.dcm
# input: input00177.dcm , gt: mask00177.dcm
# input: input00178.dcm , gt: mask00178.dcm
# input: input00179.dcm , gt: mask00179.dcm
# input: input00180.dcm , gt: mask00180.dcm
# input: input00181.dcm , gt: mask00181.dcm
# input: input00182.dcm , gt: mask00182.dcm
# input: input00183.dcm , gt: mask00183.dcm
# input: input00184.dcm , gt: mask00184.dcm
# input: input00185.dcm , gt: mask00185.dcm
# input: input00186.dcm , gt: mask00186.dcm
# input: input00187.dcm , gt: mask00187.dcm
# input: input00729.dcm , gt: mask00729.dcm
# input: input00730.dcm , gt: mask00730.dcm
# input: input00731.dcm , gt: mask00731.dcm
# input: input00732.dcm , gt: mask00732.dcm
# input: input00733.dcm , gt: mask00733.dcm
# input: input00734.dcm , gt: mask00734.dcm
# input: input00735.dcm , gt: mask00735.dcm
# input: input00736.dcm , gt: mask00736.dcm
# input: input00737.dcm , gt: mask00737.dcm
# input: input00738.dcm , gt: mask00738.dcm
# input: input00739.dcm , gt: mask00739.dcm
# input: input00740.dcm , gt: mask00740.dcm
# input: input00741.dcm , gt: mask00741.dcm
# input: input00742.dcm , gt: mask00742.dcm
# input: input00743.dcm , gt: mask00743.dcm
# input: input00744.dcm , gt: mask00744.dcm
# input: input00745.dcm , gt: mask00745.dcm
# input: input00746.dcm , gt: mask00746.dcm
# input: input00747.dcm , gt: mask00747.dcm
# input: input00748.dcm , gt: mask00748.dcm
# input: input00749.dcm , gt: mask00749.dcm
# input: input00750.dcm , gt: mask00750.dcm
# input: input00751.dcm , gt: mask00751.dcm
# input: input00752.dcm , gt: mask00752.dcm
# input: input00753.dcm , gt: mask00753.dcm
# input: input00754.dcm , gt: mask00754.dcm
# input: input00755.dcm , gt: mask00755.dcm
# input: input00756.dcm , gt: mask00756.dcm
# input: input00757.dcm , gt: mask00757.dcm
# input: input00758.dcm , gt: mask00758.dcm
# input: input00759.dcm , gt: mask00759.dcm
# input: input00760.dcm , gt: mask00760.dcm
# input: input00761.dcm , gt: mask00761.dcm
# input: input00762.dcm , gt: mask00762.dcm
# input: input00763.dcm , gt: mask00763.dcm
# input: input00764.dcm , gt: mask00764.dcm
# input: input00765.dcm , gt: mask00765.dcm
# input: input00766.dcm , gt: mask00766.dcm
# input: input00767.dcm , gt: mask00767.dcm
# input: input00768.dcm , gt: mask00768.dcm
# input: input00769.dcm , gt: mask00769.dcm
# input: input00770.dcm , gt: mask00770.dcm
# input: input00771.dcm , gt: mask00771.dcm
# input: input00772.dcm , gt: mask00772.dcm
# input: input00773.dcm , gt: mask00773.dcm
# input: input00774.dcm , gt: mask00774.dcm
# input: input00775.dcm , gt: mask00775.dcm
# input: input00776.dcm , gt: mask00776.dcm
# input: input00777.dcm , gt: mask00777.dcm
# input: input00778.dcm , gt: mask00778.dcm
# input: input00779.dcm , gt: mask00779.dcm
# input: input00780.dcm , gt: mask00780.dcm
# input: input00781.dcm , gt: mask00781.dcm
# input: input00782.dcm , gt: mask00782.dcm
# input: input00783.dcm , gt: mask00783.dcm
# input: input00784.dcm , gt: mask00784.dcm
# input: input00785.dcm , gt: mask00785.dcm
# input: input00786.dcm , gt: mask00786.dcm
# input: input00787.dcm , gt: mask00787.dcm
# input: input00788.dcm , gt: mask00788.dcm
# input: input00789.dcm , gt: mask00789.dcm
# input: input00790.dcm , gt: mask00790.dcm
# input: input00791.dcm , gt: mask00791.dcm
# input: input00792.dcm , gt: mask00792.dcm
# input: input00793.dcm , gt: mask00793.dcm
# input: input00794.dcm , gt: mask00794.dcm
# input: input00795.dcm , gt: mask00795.dcm
# input: input00796.dcm , gt: mask00796.dcm
# input: input01135.dcm , gt: mask01135.dcm
# input: input01136.dcm , gt: mask01136.dcm
# input: input01137.dcm , gt: mask01137.dcm
# input: input01138.dcm , gt: mask01138.dcm
# input: input01139.dcm , gt: mask01139.dcm
# input: input01140.dcm , gt: mask01140.dcm
# input: input01141.dcm , gt: mask01141.dcm
# input: input01142.dcm , gt: mask01142.dcm
# ...
# input: input05287.dcm , gt: mask05287.dcm
# input: input05288.dcm , gt: mask05288.dcm
# input: input05289.dcm , gt: mask05289.dcm
# input: input05290.dcm , gt: mask05290.dcm
# input: input05291.dcm , gt: mask05291.dcm
# input: input05292.dcm , gt: mask05292.dcm
# input: input05293.dcm , gt: mask05293.dcm
# input: input05294.dcm , gt: mask05294.dcm
# input: input05295.dcm , gt: mask05295.dcm
# input: input05296.dcm , gt: mask05296.dcm
# input: input05297.dcm , gt: mask05297.dcm
# input: input05298.dcm , gt: mask05298.dcm
# input: input05299.dcm , gt: mask05299.dcm
# input: input05300.dcm , gt: mask05300.dcm
# input: input05301.dcm , gt: mask05301.dcm
# input: input05302.dcm , gt: mask05302.dcm
# input: input05303.dcm , gt: mask05303.dcm
# input: input05304.dcm , gt: mask05304.dcm
# input: input05305.dcm , gt: mask05305.dcm
# input: input05306.dcm , gt: mask05306.dcm
# input: input05307.dcm , gt: mask05307.dcm
# input: input05308.dcm , gt: mask05308.dcm
# input: input05309.dcm , gt: mask05309.dcm
# input: input05310.dcm , gt: mask05310.dcm
# input: input05311.dcm , gt: mask05311.dcm
# input: input05312.dcm , gt: mask05312.dcm
# input: input05313.dcm , gt: mask05313.dcm
# input: input05314.dcm , gt: mask05314.dcm
# input: input05315.dcm , gt: mask05315.dcm
# input: input05316.dcm , gt: mask05316.dcm
# input: input05317.dcm , gt: mask05317.dcm
# input: input05318.dcm , gt: mask05318.dcm
# input: input05319.dcm , gt: mask05319.dcm
# input: input05320.dcm , gt: mask05320.dcm
# input: input05321.dcm , gt: mask05321.dcm
# input: input05322.dcm , gt: mask05322.dcm
# input: input05323.dcm , gt: mask05323.dcm
# input: input05324.dcm , gt: mask05324.dcm
# input: input05325.dcm , gt: mask05325.dcm
# input: input05326.dcm , gt: mask05326.dcm
# input: input05327.dcm , gt: mask05327.dcm
# input: input05328.dcm , gt: mask05328.dcm
# input: input05329.dcm , gt: mask05329.dcm
# input: input05330.dcm , gt: mask05330.dcm
# input: input05331.dcm , gt: mask05331.dcm
# input: input05332.dcm , gt: mask05332.dcm
# input: input05333.dcm , gt: mask05333.dcm
# input: input05334.dcm , gt: mask05334.dcm
# input: input05335.dcm , gt: mask05335.dcm
# input: input05336.dcm , gt: mask05336.dcm
# input: input05337.dcm , gt: mask05337.dcm
# input: input05338.dcm , gt: mask05338.dcm
# input: input05339.dcm , gt: mask05339.dcm
# input: input05340.dcm , gt: mask05340.dcm
# input: input05341.dcm , gt: mask05341.dcm
# input: input05342.dcm , gt: mask05342.dcm
# input: input05343.dcm , gt: mask05343.dcm
# input: input05344.dcm , gt: mask05344.dcm
# input: input05345.dcm , gt: mask05345.dcm
# input: input05346.dcm , gt: mask05346.dcm
# input: input05347.dcm , gt: mask05347.dcm
# input: input05348.dcm , gt: mask05348.dcm
# input: input05349.dcm , gt: mask05349.dcm
# input: input05350.dcm , gt: mask05350.dcm
# input: input05351.dcm , gt: mask05351.dcm
# input: input05352.dcm , gt: mask05352.dcm
# input: input05353.dcm , gt: mask05353.dcm
# input: input05354.dcm , gt: mask05354.dcm
# input: input05355.dcm , gt: mask05355.dcm
# input: input05356.dcm , gt: mask05356.dcm
# input: input05357.dcm , gt: mask05357.dcm
# input: input05358.dcm , gt: mask05358.dcm
# input: input05359.dcm , gt: mask05359.dcm
# input: input05360.dcm , gt: mask05360.dcm
# input: input05361.dcm , gt: mask05361.dcm
# input: input05362.dcm , gt: mask05362.dcm
# input: input05363.dcm , gt: mask05363.dcm
# input: input05364.dcm , gt: mask05364.dcm
# input: input05365.dcm , gt: mask05365.dcm
# input: input05366.dcm , gt: mask05366.dcm
# input: input05367.dcm , gt: mask05367.dcm
# input: input05368.dcm , gt: mask05368.dcm
# input: input05369.dcm , gt: mask05369.dcm
# input: input05370.dcm , gt: mask05370.dcm
# input: input05371.dcm , gt: mask05371.dcm
# input: input05372.dcm , gt: mask05372.dcm
# input: input05373.dcm , gt: mask05373.dcm
# input: input05374.dcm , gt: mask05374.dcm
# input: input05375.dcm , gt: mask05375.dcm
# input: input05376.dcm , gt: mask05376.dcm
# input: input05377.dcm , gt: mask05377.dcm
# input: input05378.dcm , gt: mask05378.dcm
# input: input05379.dcm , gt: mask05379.dcm
# input: input05380.dcm , gt: mask05380.dcm
# input: input05381.dcm , gt: mask05381.dcm
# input: input05382.dcm , gt: mask05382.dcm
# input: input05383.dcm , gt: mask05383.dcm
# input: input05384.dcm , gt: mask05384.dcm
# input: input05385.dcm , gt: mask05385.dcm
# input: input05386.dcm , gt: mask05386.dcm
# input: input05387.dcm , gt: mask05387.dcm
# input: input05388.dcm , gt: mask05388.dcm
# input: input05389.dcm , gt: mask05389.dcm
# input: input05390.dcm , gt: mask05390.dcm
# input: input05391.dcm , gt: mask05391.dcm
# input: input05392.dcm , gt: mask05392.dcm
# input: input05393.dcm , gt: mask05393.dcm
# input: input05394.dcm , gt: mask05394.dcm
# input: input05395.dcm , gt: mask05395.dcm
# input: input05396.dcm , gt: mask05396.dcm
# input: input05397.dcm , gt: mask05397.dcm
# input: input05398.dcm , gt: mask05398.dcm
# input: input05399.dcm , gt: mask05399.dcm
# input: input05400.dcm , gt: mask05400.dcm
# input: input05401.dcm , gt: mask05401.dcm
# input: input05402.dcm , gt: mask05402.dcm
# input: input05403.dcm , gt: mask05403.dcm
# input: input05404.dcm , gt: mask05404.dcm
# input: input05405.dcm , gt: mask05405.dcm
# input: input05406.dcm , gt: mask05406.dcm
# input: input05407.dcm , gt: mask05407.dcm
# input: input05408.dcm , gt: mask05408.dcm
# input: input05409.dcm , gt: mask05409.dcm
# input: input05410.dcm , gt: mask05410.dcm
# input: input05411.dcm , gt: mask05411.dcm
# input: input05412.dcm , gt: mask05412.dcm
# input: input05413.dcm , gt: mask05413.dcm
# input: input05414.dcm , gt: mask05414.dcm
# input: input05415.dcm , gt: mask05415.dcm
# input: input05416.dcm , gt: mask05416.dcm
# input: input05417.dcm , gt: mask05417.dcm
# input: input05418.dcm , gt: mask05418.dcm
# input: input05419.dcm , gt: mask05419.dcm
# input: input05420.dcm , gt: mask05420.dcm
# input: input05421.dcm , gt: mask05421.dcm
# input: input05422.dcm , gt: mask05422.dcm
# input: input05423.dcm , gt: mask05423.dcm
# input: input05424.dcm , gt: mask05424.dcm
# input: input05425.dcm , gt: mask05425.dcm
# input: input05426.dcm , gt: mask05426.dcm
# input: input05427.dcm , gt: mask05427.dcm
# input: input05428.dcm , gt: mask05428.dcm
# input: input05429.dcm , gt: mask05429.dcm
# input: input05430.dcm , gt: mask05430.dcm
# input: input05431.dcm , gt: mask05431.dcm
# input: input05432.dcm , gt: mask05432.dcm
# input: input05433.dcm , gt: mask05433.dcm
# input: input05434.dcm , gt: mask05434.dcm
# input: input05435.dcm , gt: mask05435.dcm
# input: input05436.dcm , gt: mask05436.dcm
# input: input05437.dcm , gt: mask05437.dcm
# input: input05438.dcm , gt: mask05438.dcm
# input: input05439.dcm , gt: mask05439.dcm
# input: input05440.dcm , gt: mask05440.dcm
# input: input05441.dcm , gt: mask05441.dcm
# input: input05442.dcm , gt: mask05442.dcm
# input: input05443.dcm , gt: mask05443.dcm
# input: input05444.dcm , gt: mask05444.dcm
# input: input05445.dcm , gt: mask05445.dcm
# input: input05446.dcm , gt: mask05446.dcm
# input: input05447.dcm , gt: mask05447.dcm
# input: input05448.dcm , gt: mask05448.dcm
# input: input05449.dcm , gt: mask05449.dcm
# input: input05450.dcm , gt: mask05450.dcm
# input: input05451.dcm , gt: mask05451.dcm
# input: input05452.dcm , gt: mask05452.dcm
# input: input05453.dcm , gt: mask05453.dcm
# input: input05454.dcm , gt: mask05454.dcm
# input: input05455.dcm , gt: mask05455.dcm
# input: input05456.dcm , gt: mask05456.dcm
# input: input05457.dcm , gt: mask05457.dcm
# input: input05458.dcm , gt: mask05458.dcm
# input: input05459.dcm , gt: mask05459.dcm
# input: input05460.dcm , gt: mask05460.dcm
# input: input05461.dcm , gt: mask05461.dcm
# input: input05462.dcm , gt: mask05462.dcm
# input: input05463.dcm , gt: mask05463.dcm
# input: input05464.dcm , gt: mask05464.dcm
# input: input05465.dcm , gt: mask05465.dcm
# input: input05466.dcm , gt: mask05466.dcm
# input: input05467.dcm , gt: mask05467.dcm
# input: input05468.dcm , gt: mask05468.dcm
# input: input05469.dcm , gt: mask05469.dcm
# input: input05470.dcm , gt: mask05470.dcm
# input: input05471.dcm , gt: mask05471.dcm
# input: input05472.dcm , gt: mask05472.dcm
# input: input05473.dcm , gt: mask05473.dcm
# input: input05474.dcm , gt: mask05474.dcm
# input: input05475.dcm , gt: mask05475.dcm
# input: input05476.dcm , gt: mask05476.dcm
# input: input05477.dcm , gt: mask05477.dcm
# input: input05478.dcm , gt: mask05478.dcm
# input: input05479.dcm , gt: mask05479.dcm
# input: input05480.dcm , gt: mask05480.dcm
# input: input05481.dcm , gt: mask05481.dcm
# input: input05482.dcm , gt: mask05482.dcm
# input: input05483.dcm , gt: mask05483.dcm
# input: input05484.dcm , gt: mask05484.dcm
# input: input05485.dcm , gt: mask05485.dcm
# input: input05486.dcm , gt: mask05486.dcm
# input: input05487.dcm , gt: mask05487.dcm
# input: input05488.dcm , gt: mask05488.dcm
# input: input05489.dcm , gt: mask05489.dcm
# input: input05490.dcm , gt: mask05490.dcm
# input: input05491.dcm , gt: mask05491.dcm
# input: input05492.dcm , gt: mask05492.dcm
# input: input05493.dcm , gt: mask05493.dcm
# input: input05494.dcm , gt: mask05494.dcm
# input: input05495.dcm , gt: mask05495.dcm
# input: input05496.dcm , gt: mask05496.dcm
# input: input05497.dcm , gt: mask05497.dcm
# input: input05498.dcm , gt: mask05498.dcm
# input: input05499.dcm , gt: mask05499.dcm
# input: input05500.dcm , gt: mask05500.dcm
# input: input05501.dcm , gt: mask05501.dcm
# input: input05502.dcm , gt: mask05502.dcm
# input: input05503.dcm , gt: mask05503.dcm
# input: input05504.dcm , gt: mask05504.dcm
# input: input05505.dcm , gt: mask05505.dcm
# input: input05506.dcm , gt: mask05506.dcm
# input: input05507.dcm , gt: mask05507.dcm
# input: input05508.dcm , gt: mask05508.dcm
# input: input05509.dcm , gt: mask05509.dcm
# input: input05510.dcm , gt: mask05510.dcm
# input: input05511.dcm , gt: mask05511.dcm
# input: input05512.dcm , gt: mask05512.dcm
# input: input05513.dcm , gt: mask05513.dcm
# input: input05514.dcm , gt: mask05514.dcm
# input: input05515.dcm , gt: mask05515.dcm
# input: input05516.dcm , gt: mask05516.dcm
# input: input05517.dcm , gt: mask05517.dcm
# input: input05518.dcm , gt: mask05518.dcm
# input: input05519.dcm , gt: mask05519.dcm
# input: input05520.dcm , gt: mask05520.dcm
# input: input05521.dcm , gt: mask05521.dcm
# input: input05522.dcm , gt: mask05522.dcm
# input: input05523.dcm , gt: mask05523.dcm
# input: input05524.dcm , gt: mask05524.dcm
# input: input05525.dcm , gt: mask05525.dcm
# input: input05526.dcm , gt: mask05526.dcm
# input: input05527.dcm , gt: mask05527.dcm
# input: input05528.dcm , gt: mask05528.dcm
# input: input05529.dcm , gt: mask05529.dcm
# input: input05530.dcm , gt: mask05530.dcm
# input: input05531.dcm , gt: mask05531.dcm
# input: input05532.dcm , gt: mask05532.dcm
# input: input05533.dcm , gt: mask05533.dcm
# input: input05534.dcm , gt: mask05534.dcm
# input: input05535.dcm , gt: mask05535.dcm
# input: input05536.dcm , gt: mask05536.dcm
# input: input05537.dcm , gt: mask05537.dcm
# input: input05538.dcm , gt: mask05538.dcm
# input: input05539.dcm , gt: mask05539.dcm
# input: input05540.dcm , gt: mask05540.dcm
# input: input05541.dcm , gt: mask05541.dcm
# input: input05542.dcm , gt: mask05542.dcm
# input: input05543.dcm , gt: mask05543.dcm
# input: input05544.dcm , gt: mask05544.dcm
# input: input05545.dcm , gt: mask05545.dcm
# input: input05546.dcm , gt: mask05546.dcm
# input: input05547.dcm , gt: mask05547.dcm
# input: input05548.dcm , gt: mask05548.dcm
# input: input05549.dcm , gt: mask05549.dcm
# input: input05550.dcm , gt: mask05550.dcm
# input: input05551.dcm , gt: mask05551.dcm
# input: input05552.dcm , gt: mask05552.dcm
# input: input05553.dcm , gt: mask05553.dcm
# input: input05554.dcm , gt: mask05554.dcm
# input: input05555.dcm , gt: mask05555.dcm
# input: input05556.dcm , gt: mask05556.dcm
# input: input05557.dcm , gt: mask05557.dcm
# input: input05558.dcm , gt: mask05558.dcm
# input: input05559.dcm , gt: mask05559.dcm
# input: input05560.dcm , gt: mask05560.dcm
# input: input05561.dcm , gt: mask05561.dcm
# input: input05562.dcm , gt: mask05562.dcm
# input: input05563.dcm , gt: mask05563.dcm
# input: input05564.dcm , gt: mask05564.dcm
# input: input05565.dcm , gt: mask05565.dcm
# input: input05566.dcm , gt: mask05566.dcm
# input: input05567.dcm , gt: mask05567.dcm
# input: input05568.dcm , gt: mask05568.dcm
# input: input05569.dcm , gt: mask05569.dcm
# input: input05570.dcm , gt: mask05570.dcm
# input: input05571.dcm , gt: mask05571.dcm
# input: input05572.dcm , gt: mask05572.dcm
# input: input05573.dcm , gt: mask05573.dcm
# input: input05574.dcm , gt: mask05574.dcm
# input: input05575.dcm , gt: mask05575.dcm
# input: input05576.dcm , gt: mask05576.dcm
# input: input05577.dcm , gt: mask05577.dcm
# input: input05578.dcm , gt: mask05578.dcm
# input: input05579.dcm , gt: mask05579.dcm
# input: input05580.dcm , gt: mask05580.dcm
# input: input05581.dcm , gt: mask05581.dcm
# input: input05582.dcm , gt: mask05582.dcm
# input: input05583.dcm , gt: mask05583.dcm
# input: input05584.dcm , gt: mask05584.dcm
# input: input05585.dcm , gt: mask05585.dcm
# input: input05586.dcm , gt: mask05586.dcm
# input: input05587.dcm , gt: mask05587.dcm
# input: input05588.dcm , gt: mask05588.dcm
# input: input05589.dcm , gt: mask05589.dcm
# input: input05590.dcm , gt: mask05590.dcm
# input: input05591.dcm , gt: mask05591.dcm
# input: input05592.dcm , gt: mask05592.dcm
# input: input05593.dcm , gt: mask05593.dcm
# input: input05594.dcm , gt: mask05594.dcm
# input: input05595.dcm , gt: mask05595.dcm
# input: input05596.dcm , gt: mask05596.dcm
# input: input05597.dcm , gt: mask05597.dcm
# input: input05598.dcm , gt: mask05598.dcm
# input: input05599.dcm , gt: mask05599.dcm
# input: input05600.dcm , gt: mask05600.dcm
# input: input05601.dcm , gt: mask05601.dcm
# input: input05602.dcm , gt: mask05602.dcm
# input: input05603.dcm , gt: mask05603.dcm
# input: input05604.dcm , gt: mask05604.dcm
# input: input05605.dcm , gt: mask05605.dcm
# input: input05606.dcm , gt: mask05606.dcm
# input: input05607.dcm , gt: mask05607.dcm
# input: input05608.dcm , gt: mask05608.dcm
# input: input05609.dcm , gt: mask05609.dcm
# input: input05610.dcm , gt: mask05610.dcm
# input: input05611.dcm , gt: mask05611.dcm
# input: input05612.dcm , gt: mask05612.dcm
# input: input05613.dcm , gt: mask05613.dcm
# input: input05614.dcm , gt: mask05614.dcm
# input: input05615.dcm , gt: mask05615.dcm
# input: input05616.dcm , gt: mask05616.dcm
# input: input05617.dcm , gt: mask05617.dcm
# input: input05618.dcm , gt: mask05618.dcm
# input: input05619.dcm , gt: mask05619.dcm
# input: input05620.dcm , gt: mask05620.dcm
# input: input05621.dcm , gt: mask05621.dcm
# input: input05622.dcm , gt: mask05622.dcm
# input: input05623.dcm , gt: mask05623.dcm
# input: input05624.dcm , gt: mask05624.dcm
# input: input05625.dcm , gt: mask05625.dcm
# input: input05626.dcm , gt: mask05626.dcm
# input: input05627.dcm , gt: mask05627.dcm
# input: input05628.dcm , gt: mask05628.dcm
# input: input05629.dcm , gt: mask05629.dcm
# input: input05630.dcm , gt: mask05630.dcm
# input: input05631.dcm , gt: mask05631.dcm
# input: input05632.dcm , gt: mask05632.dcm
# input: input05633.dcm , gt: mask05633.dcm
# input: input05634.dcm , gt: mask05634.dcm
# input: input05635.dcm , gt: mask05635.dcm
# input: input05636.dcm , gt: mask05636.dcm
# input: input05637.dcm , gt: mask05637.dcm
# input: input05638.dcm , gt: mask05638.dcm
# input: input05639.dcm , gt: mask05639.dcm
# input: input05640.dcm , gt: mask05640.dcm
# input: input05641.dcm , gt: mask05641.dcm
# input: input05642.dcm , gt: mask05642.dcm
# input: input05643.dcm , gt: mask05643.dcm
# input: input05644.dcm , gt: mask05644.dcm
# input: input05645.dcm , gt: mask05645.dcm
# input: input05646.dcm , gt: mask05646.dcm
# --------------------------------------------------
# Recal: Avg:0.96 , Max: 1.00 , Min: 0.00
# --------------------------------------------------
# Precision: Avg:0.95 , Max: 1.00 , Min: 0.00
# --------------------------------------------------
# False Positive Rate: Avg:0.00 , Max: 0.01 , Min: 0.00
# --------------------------------------------------
# Calculate False Negative Rate: Avg:0.04 , Max: 0.84 , Min: 0.00
# --------------------------------------------------
# Percentage of Wrong Classifications: Avg:0.14 , Max: 3.02 , Min: 0.00
# --------------------------------------------------
# Jaccard: Avg:0.92 , Max: 1.00 , Min: 0.00
# --------------------------------------------------
# Dice: Avg:0.95 , Max: 1.00 , Min: 0.00
# --------------------------------------------------
# --------------------------------------------------
# Confusion Matrix
# --------------------------------------------------

# %%
datadir ='C://Users/1/Desktop/SIO/head/'

input_folder = os.path.join(datadir,'CT')
bone_masks_folder = os.path.join(datadir,'labels')

# image files
input_files = glob.glob(os.path.join(input_folder,'*.tif'))  
bone_mask_files = glob.glob(os.path.join(bone_masks_folder,'*.tif'))   


input_files.sort()
bone_mask_files.sort()

assert(len(input_files) == len(bone_mask_files))


data = []
for input_image, bone_mask_image in zip(input_files, bone_mask_files):
    
    data.append((input_image,bone_mask_image))

# some samples from dataset
n_samples = 5

for i in range(n_samples):
    
    #  size of images
    f, (ax1, ax2) = plt.subplots(1, 2)
    f.set_figwidth(10)
    
    # random sample
    idx = np.random.randint(0, len(data))
    input_image_path, bone_mask_image_path = data[idx]
    
    input_image = cv2.imread(input_image_path)
    bone_mask_image = cv2.imread(bone_mask_image_path) 
    
    ax1.imshow(input_image, cmap = 'gray')
    ax1.set_title('Input Image # {0}'.format(idx))
    
    ax2.imshow(bone_mask_image, cmap = 'gray')
    ax2.set_title('Bone Mask Image # {0}'.format(idx))
